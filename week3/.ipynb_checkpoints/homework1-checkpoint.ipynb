# %%
import pandas as pd
df = pd.read_csv("data/train.csv")
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[["Sex","Age","SibSp","Parch"]]
# Out:
#         Sex   Age  SibSp  Parch
# 0      male  22.0      1      0
# 1    female  38.0      1      0
# 2    female  26.0      0      0
# 3    female  35.0      1      0
# 4      male  35.0      0      0
# ..      ...   ...    ...    ...
# 886    male  27.0      0      0
# 887  female  19.0      0      0
# 888  female   NaN      1      2
# 889    male  26.0      0      0
# 890    male  32.0      0      0
#
# [891 rows x 4 columns]

# %%
df_test = pd.read_csv("data/test.csv")
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.loc[df["Age"]<10, "Age"] = 0
df.loc[(df["Age"]>=10) & (df["Age"]<20), "Age"] = 10
df.loc[(df["Age"]>=20) & (df["Age"]<30), "Age"] = 20
df.loc[(df["Age"]>=30) & (df["Age"]<40), "Age"] = 30
df.loc[(df["Age"]>=40) & (df["Age"]<50), "Age"] = 40
df.loc[df["Age"]>=50, "Age"] = 50
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  20.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  30.0      1
# 2                               Heikkinen, Miss. Laina  female  20.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  30.0      1
# 4                             Allen, Mr. William Henry    male  30.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  20.0      0
# 887                       Graham, Miss. Margaret Edith  female  10.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  20.0      0
# 890                                Dooley, Mr. Patrick    male  30.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df_test.loc[df_test["Age"]<10, "Age"] = 0
df_test.loc[(df_test["Age"]>=10) & (df_test["Age"]<20), "Age"] = 10
df_test.loc[(df_test["Age"]>=20) & (df_test["Age"]<30), "Age"] = 20
df_test.loc[(df_test["Age"]>=30) & (df_test["Age"]<40), "Age"] = 30
df_test.loc[(df_test["Age"]>=40) & (df_test["Age"]<50), "Age"] = 40
df_test.loc[df_test["Age"]>=50, "Age"] = 50
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  30.0      0      0              330911    7.8292   NaN        Q
# 1    female  40.0      1      0              363272    7.0000   NaN        S
# 2      male  50.0      0      0              240276    9.6875   NaN        Q
# 3      male  20.0      0      0              315154    8.6625   NaN        S
# 4    female  20.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  30.0      0      0            PC 17758  108.9000  C105        C
# 415    male  30.0      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
df["FamilySize"] = df["SibSp"] + df["Parch"]
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  20.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  30.0      1
# 2                             Heikkinen, Miss. Laina  female  20.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  30.0      1
# 4                           Allen, Mr. William Henry    male  30.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           1
# 1      0          PC 17599  71.2833   C85        C           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0
# 3      0            113803  53.1000  C123        S           1
# 4      0            373450   8.0500   NaN        S           0

# %%
df_test["FamilySize"] = df_test["SibSp"] + df_test["Parch"]
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  FamilySize
# 0  30.0      0      0   330911   7.8292   NaN        Q           0
# 1  40.0      1      0   363272   7.0000   NaN        S           1
# 2  50.0      0      0   240276   9.6875   NaN        Q           0
# 3  20.0      0      0   315154   8.6625   NaN        S           0
# 4  20.0      1      1  3101298  12.2875   NaN        S           2

# %%
train = df[["Survived", "Sex", "Age", "FamilySize"]]
test = df_test[["Sex", "Age", "FamilySize"]]
train.head()
# Out:
#    Survived     Sex   Age  FamilySize
# 0         0    male  20.0           1
# 1         1  female  30.0           1
# 2         1  female  20.0           0
# 3         1  female  30.0           1
# 4         0    male  30.0           0

# %%
df["Fare"] = df["Fare"].fillna(df["Fare"].mean())
df_test["Fare"] = df_test["Fare"].fillna(df_test["Fare"].mean())
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  FamilySize
# 0  30.0      0      0   330911   7.8292   NaN        Q           0
# 1  40.0      1      0   363272   7.0000   NaN        S           1
# 2  50.0      0      0   240276   9.6875   NaN        Q           0
# 3  20.0      0      0   315154   8.6625   NaN        S           0
# 4  20.0      1      1  3101298  12.2875   NaN        S           2

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# FamilySize       0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# FamilySize       0
# dtype: int64

# %%
df["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df["Embarked"] = df["Embarked"].fillna("S")

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# FamilySize       0
# dtype: int64

# %%
df_test["Embarked"] = df_test["Embarked"].fillna("S")

# %%
train = df[["Survived", "Sex", "Age", "FamilySize", "Fare", "Embarked"]]
test = df_test[["Sex", "Age", "FamilySize", "Fare", "Embarked"]]
train.head()
# Out:
#    Survived     Sex   Age  FamilySize     Fare Embarked
# 0         0    male  20.0           1   7.2500        S
# 1         1  female  30.0           1  71.2833        C
# 2         1  female  20.0           0   7.9250        S
# 3         1  female  30.0           1  53.1000        S
# 4         0    male  30.0           0   8.0500        S

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  20.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  30.0      1
# 2                               Heikkinen, Miss. Laina  female  20.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  30.0      1
# 4                             Allen, Mr. William Henry    male  30.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  20.0      0
# 887                       Graham, Miss. Margaret Edith  female  10.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  20.0      0
# 890                                Dooley, Mr. Patrick    male  30.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0        0         A/5 21171   7.2500   NaN        S           1
# 1        0          PC 17599  71.2833   C85        C           1
# 2        0  STON/O2. 3101282   7.9250   NaN        S           0
# 3        0            113803  53.1000  C123        S           1
# 4        0            373450   8.0500   NaN        S           0
# ..     ...               ...      ...   ...      ...         ...
# 886      0            211536  13.0000   NaN        S           0
# 887      0            112053  30.0000   B42        S           0
# 888      2        W./C. 6607  23.4500   NaN        S           3
# 889      0            111369  30.0000  C148        C           0
# 890      0            370376   7.7500   NaN        Q           0
#
# [891 rows x 13 columns]

# %%
df.loc[df["Name"].str.contains("Mr\."), "Name"] = "Mr"
df.loc[df["Name"].str.contains("Mrs\."), "Name"] = "Mrs"
df.loc[df["Name"].str.contains("Miss\."), "Name"] = "Miss"

# %%
df["Name"] = df["Name"].map({
    "Mr": 0,
    "Mrs": 1,
    "Miss": 2
})
df["Name"] = df["Name"].fillna(3)
df
# Out:
#      PassengerId  Survived  Pclass  Name     Sex   Age  SibSp  Parch  \
# 0              1         0       3   0.0    male  20.0      1      0
# 1              2         1       1   1.0  female  30.0      1      0
# 2              3         1       3   2.0  female  20.0      0      0
# 3              4         1       1   1.0  female  30.0      1      0
# 4              5         0       3   0.0    male  30.0      0      0
# ..           ...       ...     ...   ...     ...   ...    ...    ...
# 886          887         0       2   3.0    male  20.0      0      0
# 887          888         1       1   2.0  female  10.0      0      0
# 888          889         0       3   2.0  female   NaN      1      2
# 889          890         1       1   0.0    male  20.0      0      0
# 890          891         0       3   0.0    male  30.0      0      0
#
#                Ticket     Fare Cabin Embarked  FamilySize
# 0           A/5 21171   7.2500   NaN        S           1
# 1            PC 17599  71.2833   C85        C           1
# 2    STON/O2. 3101282   7.9250   NaN        S           0
# 3              113803  53.1000  C123        S           1
# 4              373450   8.0500   NaN        S           0
# ..                ...      ...   ...      ...         ...
# 886            211536  13.0000   NaN        S           0
# 887            112053  30.0000   B42        S           0
# 888        W./C. 6607  23.4500   NaN        S           3
# 889            111369  30.0000  C148        C           0
# 890            370376   7.7500   NaN        Q           0
#
# [891 rows x 13 columns]

# %%
df["Age"] = df["Age"].fillna(df.groupby("Name")["Age"].transform("mean"))
df
# Out:
#      PassengerId  Survived  Pclass  Name     Sex        Age  SibSp  Parch  \
# 0              1         0       3   0.0    male  20.000000      1      0
# 1              2         1       1   1.0  female  30.000000      1      0
# 2              3         1       3   2.0  female  20.000000      0      0
# 3              4         1       1   1.0  female  30.000000      1      0
# 4              5         0       3   0.0    male  30.000000      0      0
# ..           ...       ...     ...   ...     ...        ...    ...    ...
# 886          887         0       2   3.0    male  20.000000      0      0
# 887          888         1       1   2.0  female  10.000000      0      0
# 888          889         0       3   2.0  female  17.465753      1      2
# 889          890         1       1   0.0    male  20.000000      0      0
# 890          891         0       3   0.0    male  30.000000      0      0
#
#                Ticket     Fare Cabin Embarked  FamilySize
# 0           A/5 21171   7.2500   NaN        S           1
# 1            PC 17599  71.2833   C85        C           1
# 2    STON/O2. 3101282   7.9250   NaN        S           0
# 3              113803  53.1000  C123        S           1
# 4              373450   8.0500   NaN        S           0
# ..                ...      ...   ...      ...         ...
# 886            211536  13.0000   NaN        S           0
# 887            112053  30.0000   B42        S           0
# 888        W./C. 6607  23.4500   NaN        S           3
# 889            111369  30.0000  C148        C           0
# 890            370376   7.7500   NaN        Q           0
#
# [891 rows x 13 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
facet = sns.FacetGrid(df, hue="Survived", aspect=4)
facet.map(sns.kdeplot, "Age")
facet.add_legend()

plt.show()
